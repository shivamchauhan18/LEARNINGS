# %% [markdown]
# ### Assignment-1: Python Basics & Variables

# %%
# 1. Print Your Name

print("Shivam Chauhan")
# Out:
# Shivam Chauhan

# %%
# 2. Comments in Python

# Single line comment
""" Multiline comment """
# Out:
# ' Multiline comment '

# %%
# 3. Working with Basic Data Types

# Integer
print(type(5))

# Float
print(type(5.4))

# Boolean
print( type(2==2))

# String
print(type("shivam"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
# 4. Local vs Global Variables
x = 54

def change_x(t):
    global x 
    x = t

change_x(40)    
print(x)
# Out:
# 40

# %%
# 5.Dynamic Typing & Type Checking

x = 10
print(x, type(x))

x = 3.14
print(x, type(x))

x = "Hello"
print(x, type(x))

x = True
print(x, type(x))

x = [1, 2, 3]
print(x, type(x))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Hello <class 'str'>
# True <class 'bool'>
# [1, 2, 3] <class 'list'>

# %%
# 6. User Input Practice

name = input("Name: ")
age = int(input("Age: "))

print("Name:", name)
print("Age:", age)
# Out:
# Name: shivam
# Age: 25
