# %%
# Write a program to concatenate two strings using the + operator.

string_1 = " Shivam is"
srting_2 = " good boy"

print(string_1 + srting_2)
# Out:
#  Shivam is good boy
# [2, 3, 4, 5]

# %%
# Write a program to find the length of a string using a built-in function.

string = "shivam"
len(string)
# Out:
# 6

# %%
# Write a program to extract a substring from a string using slicing.

string = "shivam is a good boy"

string[7:10]
# Out:
# 'is '

# %% [markdown]
# Write a program to:
#
# Find the position of a substring using:
#
# find()
# index()
#
# Handle the case when the substring is not found

# %%
string = "Shivam is good boy"

try:
    print(string.index("goodi"))
except Exception as e:
    print("value error")

string.find("isi")
# Out:
# value error
# 'S'

# %%
# Write a program to compare two strings using:

a = "Sh1vam"
b = "shiavm"

a = a.lower()
b = b.lower()

if len(a) == len(b):
    for i in range(len(a)):
        
        if a[i] != b[i]:
            print("no")
            break
    else: 
        print("same")
else: 
    print("no")
# Out:
# no

# %%
# Write a program to remove leading and trailing spaces using strip().

st = "shi vam "
st =st.replace(" ", "")
st
# Out:
# 'shivam'

# %%
text = "Hello World Python"

words = text.split()

print(words)
# Out:
# ['Hello', 'World', 'Python']
